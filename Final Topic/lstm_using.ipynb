# %%
import jieba
from urllib.request import urlretrieve
url = "https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big"
urlretrieve(url, "dict.txt.big")
jieba.set_dictionary("dict.txt.big")

# %%
def commentcut(s):
    s = s.replace(" ", "").replace(":", "").replace("n", "").replace("r", "").replace("r", "...")
    s = " ".join(jieba.cut(s))
    
    return s

# %%
import pandas as pd

df = pd.read_table("pos_chi.txt")
len(df["content"])
for i , j in enumerate(df["content"]):
    if len(j)<9:
        df = df.drop([i])
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                content
# 0                    好 感謝一樓大大，我來裝看看！感恩
# 1             S6 Lite 入門就 64G，還送不錯的筆跟套
# 2                S5E 螢幕好很多 常使用就買比較不傷眼的
# 3           你有買很好啊！不要像有個人自稱有買note10嫌體驗
# 4          SE2就續航差 小螢幕 大尺寸 高效時會過熱降頻 大多
# ...                                ...
# 47440              至少我覺得sony的機子外型與配色好看
# 47441                    我看是半斤八兩啦哈哈哈哈哈
# 47442  一樓爽粉好兇。                     我喜歡
# 47443        推Z2a，用起來超爽的！螢幕只要別和最新的比較的話
# 47444       然後5V座充充電可以吃到約1.5A，充起來算是挺快的
#
# [47445 rows x 1 columns]

# %%
import re
punctuation = """@/1 ，！？｡＂"＃'~,、+!.\＄％＆*＇（）＊＋－／：；＜＝＞＠［＼］＾＿｀｛｜｝～｟｠｢｣､、〃》「」『』【】〔〕〖〗〘〙〚〛〜〝〞〟〰〾〿–—‘'‛“”„‟…‧﹏"""
re_punctuation = "[{}]+".format(punctuation)
for i in range(0, len(df["content"])):
    df["content"][i] = re.sub(re_punctuation, "", df["content"][i])
df
# Out:
#                         content
# 0                好感謝一樓大大我來裝看看感恩
# 1          S6Lite入門就64G還送不錯的筆跟套
# 2           S5E螢幕好很多常使用就買比較不傷眼的
# 3      你有買很好啊不要像有個人自稱有買note0嫌體驗
# 4       SE2就續航差小螢幕大尺寸高效時會過熱降頻大多
# ...                         ...
# 47440       至少我覺得sony的機子外型與配色好看
# 47441             我看是半斤八兩啦哈哈哈哈哈
# 47442                一樓爽粉好兇。我喜歡
# 47443   推Z2a用起來超爽的螢幕只要別和最新的比較的話
# 47444   然後5V座充充電可以吃到約5A充起來算是挺快的
#
# [47445 rows x 1 columns]

# %%
df["content"] = df["content"].apply(commentcut)
df
# Out:
# Building prefix dict from D:\Users\Administrator\PycharmProjects\專題\dict.txt.big ...
# Dumping model to file cache d:\Users\ADMINI~1\AppData\Local\Temp\jieba.u88df494de78ded9baf9099ad8179b741.cache
# Loading model cost 2.600 seconds.
# Prefix dict has been built successfully.
#                                       content
# 0                        好 感謝 一樓 大大 我來裝 看看 感恩
# 1                 S6Lite 入門 就 64G 還送 不錯 的 筆跟套
# 2              S5E 螢幕 好 很多 常 使用 就 買 比較 不 傷眼 的
# 3      你 有 買 很 好 啊 不要 像 有 個人 自稱 有 買 ote0 嫌 體驗
# 4          SE2 就 續航 差小 螢幕 大 尺寸 高效 時會 過熱 降頻 大多
# ...                                       ...
# 47440             至少 我 覺得 soy 的 機子 外型 與 配色 好看
# 47441                     我 看 是 半斤八兩 啦 哈哈哈 哈哈
# 47442                        一樓 爽粉 好 兇 。 我 喜歡
# 47443    推 Z2a 用 起來 超爽 的 螢幕 只要 別 和 最新 的 比較 的話
# 47444    然後 5V 座充 充電 可以 吃 到 約 5A 充 起來 算是 挺快 的
#
# [47445 rows x 1 columns]

# %%
# Import the necessary modules
import pickle
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences


# 匯入字典
with open('tokenizer.pk', 'rb') as f:
    tok = pickle.load(f)
with open('lstm_label_dict.pk', 'rb') as f:
    output_dictionary = pickle.load(f)

# 載入模型
model_save_path = 'lstm_model.h5'
lstm_model = load_model(model_save_path)

# %%
for i in df["content"][0:100]:
    print(i)
# Out:
# 好 感謝 一樓 大大 我來裝 看看 感恩
# S6Lite 入門 就 64G 還送 不錯 的 筆跟套
# S5E 螢幕 好 很多 常 使用 就 買 比較 不 傷眼 的
# 你 有 買 很 好 啊 不要 像 有 個人 自稱 有 買 ote0 嫌 體驗
# SE2 就 續航 差小 螢幕 大 尺寸 高效 時會 過熱 降頻 大多
# 樓上 說 的 太好了 那 我們 應該 先來 分中階 低階
# 過了 四年 還 念念不忘 信仰 就是 狂
# 當 了 四次 多 打 看錯
# 哈哈哈 釣出 一堆 超 好笑
# kai 好 啦 好 啦 adoid 高階 超好 用 這樣 有 可信度 了
# 刻 一下 經典 機身 來 致敬 一下 也 是 剛好 而已 5k 手機 續
# 結果 測試 影片 全部 都 輸 se2 一點點 還能 得出 打破 adoi
# 了 不得不 喊 香卓粉 的 信仰 果然 不容 你 我 質疑
# 選 iPhoe 問題 很 簡單 效能 好 系統 穩定 存取速度 優
# 效能 好 系統 穩定 但是 比賽 的 時候 會 斷線 導致 爭議
# 很 開心 的 一 起來 罵 的 有心人士
# 安卓 的 毛病 就 出 在 機身 尺寸 跟 SE 一樣 但是 螢幕 大了許
# 哈哈 你好 了解 我 傳說 是 用 平板 玩 啦 不過 它 也 不是 新機 了 所以 想 換新 手機 玩
# A2 效能 比較 好 iPhoe 可以 接線 傳 照片 影片 到 電腦 0502
# 感謝 解答 X2
# 你 用 八年 可以 把 ote 當 信仰 了 買 ote 吧 0502
# ote04 哈哈 所以 我安卓 的 優先 選 ote 系列 啊
# 猛用 八年 N20502
# 8 年 好 猛 0502
# 手機 可以 用 8 年 當真 神人 了 0502
# 當然 是 ote0 可以 用 八年 真 厲害 佩服
# 二個 都 蠻 符合 你 的 需求 的 可以 選 CP 高 的
# 老 實說 買 ote0 跟 iphoe 這 2 隻 cp 值會 好 非常 多
# ipad 也 是 大 螢幕 iphoe 啊 不能 取代 筆電 而且 返回
# 綠狗卡 綁 成功 綁 成功
# 我 拿 歐版 美版 的 三星 都 可以 辨認 台灣 的 信用卡 喔
# 堅持 全 螢幕 讓 各 大廠 RD 變 智障
# 真的 覺得 像 S9 那樣 留 一點點 點點 的 額頭 很棒 啊
# 感謝 各位 的 建議 我會 去 買 防水 套 來用 的
# 買 防水 套 才 是 真 防水 任何 標榜 防水 的 手機 受潮 維修
# 超聲波 目前 很 好 用 耶
# 我 耳朵 也 滿油 的 用 AiPodPo 很 牢固 哦
# 下次 可 以來 個 凹面 螢幕 進去 嗎
# 曲面 視覺 很爽 又 漂亮 用 習慣 就 不 容易 誤觸 了
# Note0 有 好 有趣 喔 還有 哪些 動物 有 呢
# 感覺 好 好玩 我 也 要來 試試看
# s0 最 可惜 就是 電量 手感 真的 好
# Note9 已經 算是 續航 很棒 的 三星 旗艦 了
# 哈哈 手感 真的 很 重要
# 如果 SOT 有 8 小時 那 也 真的 很 不錯 了 0323
# 減亮 螢幕 乘 0770323
# 我 Adoid9 成功 開卡 拿到 全家 禮券
# SP 悠遊 卡 帳戶 連結 自動 加值 第一筆 交易 成功 好用
# 還有 三星 送 的 50 元買杯 咖啡 爽
# 很多 續 399 的 都 是 公司 有 補助 吧
# mobilepay 討論 很 多次 了 窩 就是 有鎖 地區
# 我 S0 一次 成功 新增 卡 片時 沒開 fc
# 咦 我 用 手勢 玉山 pi 有 加值 成功 說 039
# 值 一直 跳 錯誤 今天 再 嘗試 就 可以 了
# 而且 今天 才 收到 記名 成功 通知 哈哈哈
# 感覺 很 不錯 耶早 用 早 感受 5G
# 其他 顏色 我 覺得 都 蠻 好看 的
# 私以 為 S0 系列 的 絢光 背 是 史 上 最美 三星 機超 愛
# s20 晴空 藍 路過 真的 漂亮 又 順暢 好 讚
# 這個 藍色 實機 真的 蠻 好看 的 我 也 是 藍色
# 螢幕 當然 OLED 對比 好看 囉
# 好 想 看 BT2 背蓋 實品
# 實機 質感 很棒 。 但 反光 時 有點 廉價
# S 系列 打 年輕 和 小資 族群 這 顏色 很 適合 啊 用 重色 就
# 感覺 還 不錯 啊 雖然 我 覺得 S0 的 絢光白 最 好看
# 恭喜 入手 我 也 拿 了 一台 晴空 藍 但 我 覺得 最 好看 的 是
# 解鎖 速度 還是 比盲 按 S20 快 的 成功率 也 很 高
# 華為 的 指節 截圖 最棒
# 原廠 貼 好 保護 貼 跟 送 透明 保護 殼 我 覺得 滿 貼心 的 XD
# 20hz 真的 很 有感 更新快 到 眼睛 不 習慣
# 重複 認證 第二個 以 下面 為主 。 你 會 發現 很 好 解鎖
# 悠遊 卡 的 好處 全部 便利商店 都 可以 買 東西 信用卡 只
# 微軟 喔 加油 捏 xboxlik
# 不用 切 回來 所以 是 開 了 payapp 他 就 會 自己 優先 用
# 期待 明天 拿到 s20
# 好處 就是 方便 懶人 啊
# 對於 喜歡 各 廠牌 旗艦機 換來換去 的 人 還是 繼續 用 NFC -
# 借問 有人 最近 samsugpay 常駐 在 首頁 的 小 工具 常
# 而是 得 手動 操作 加值 每次 你 可以 選 不同 卡
# 這樣 我 可以 放心 開通 了 XD
# 很 實用 推 037
# 有 學生 卡 跪求 下放 037
# 嗚嗚 好 希望 a50 升級 後 會 有 037
# 縱 即逝 的 037
# 現在 信用卡 搭配 行動 支付 回饋 很多 大概 只有 方便 常 搭 037
# 不用 開 app 跟 蘋果 的 快速 交通 模式 一樣 037
# 等等 去 試試看 037
# 280 可以 手機 上 買超 吸引 人 的
# 給我 下載 037
# 超商 操作 。 都還沒 實際 去 刷 等 會 試試 。 037
# 買 N9 的 爽到 037
# sp 儲值 可以 噢 只要 sp 內有 綁定 支援 的 銀行 信用卡 即可
# ote9 可以 用 我 朋友 有 成功
# 5W 有線 快充 FidX2po 值得 擁有 但是 要 臺幣 近 三
# 原來如此 感謝 分享
# 老婆 推薦 A7 當初 我 老婆 換 AISTAR 到 現在 還是 很 滿意
# 一件 新品 可以 發 一篇 超好 洗 。
# 有 全系列 可以 去 玩 了 XD
# 三星 不愧 是 全球 智慧型 手機 的 霸主 讚
# 早 在 用 遠傳 的 fc 悠遊 卡 了 很 方便 而且 可以 設定 自

# %%
pos = 0
neg = 0
count = 0
for i in df["content"][0:100]:
    # 資料預處理
    # sent = ["S5E 螢幕 好 很多 常 使用 就 買 比較 不 傷眼 的"]
    # tok = Tokenizer(num_words=20000)
    # tok.fit_on_texts(x)

    x = tok.texts_to_sequences([i])
    x_pad = pad_sequences(x, maxlen=128)
    # print(x_pad)

    # 模型預測
    y_predict = lstm_model.predict(x_pad)
    label_dict = {v:k for k,v in output_dictionary.items()}
    # print('輸入語句: %s' % sent)
    # print('情感預測結果: %s' % label_dict[np.argmax(y_predict)])
    if np.argmax(y_predict) == 0:
        neg += 1
        print(i)
    elif np.argmax(y_predict) == 1:
        pos += 1
    count += 1
print(f"在{count}則正向評論中，您的預測準度為:", 100*round(float(pos/count), 2),"%")
# Out:
# 樓上 說 的 太好了 那 我們 應該 先來 分中階 低階
# 當 了 四次 多 打 看錯
# 結果 測試 影片 全部 都 輸 se2 一點點 還能 得出 打破 adoi
# 很 開心 的 一 起來 罵 的 有心人士
# 猛用 八年 N20502
# 綠狗卡 綁 成功 綁 成功
# 堅持 全 螢幕 讓 各 大廠 RD 變 智障
# 下次 可 以來 個 凹面 螢幕 進去 嗎
# 曲面 視覺 很爽 又 漂亮 用 習慣 就 不 容易 誤觸 了
# 如果 SOT 有 8 小時 那 也 真的 很 不錯 了 0323
# 減亮 螢幕 乘 0770323
# 我 Adoid9 成功 開卡 拿到 全家 禮券
# SP 悠遊 卡 帳戶 連結 自動 加值 第一筆 交易 成功 好用
# 我 S0 一次 成功 新增 卡 片時 沒開 fc
# 咦 我 用 手勢 玉山 pi 有 加值 成功 說 039
# 而且 今天 才 收到 記名 成功 通知 哈哈哈
# 感覺 很 不錯 耶早 用 早 感受 5G
# 私以 為 S0 系列 的 絢光 背 是 史 上 最美 三星 機超 愛
# S 系列 打 年輕 和 小資 族群 這 顏色 很 適合 啊 用 重色 就
# 華為 的 指節 截圖 最棒
# 原廠 貼 好 保護 貼 跟 送 透明 保護 殼 我 覺得 滿 貼心 的 XD
# 不用 切 回來 所以 是 開 了 payapp 他 就 會 自己 優先 用
# 好處 就是 方便 懶人 啊
# 借問 有人 最近 samsugpay 常駐 在 首頁 的 小 工具 常
# 而是 得 手動 操作 加值 每次 你 可以 選 不同 卡
# 很 實用 推 037
# 縱 即逝 的 037
# 現在 信用卡 搭配 行動 支付 回饋 很多 大概 只有 方便 常 搭 037
# 不用 開 app 跟 蘋果 的 快速 交通 模式 一樣 037
# 等等 去 試試看 037
# 給我 下載 037
# 超商 操作 。 都還沒 實際 去 刷 等 會 試試 。 037
# sp 儲值 可以 噢 只要 sp 內有 綁定 支援 的 銀行 信用卡 即可
# 三星 不愧 是 全球 智慧型 手機 的 霸主 讚
# 早 在 用 遠傳 的 fc 悠遊 卡 了 很 方便 而且 可以 設定 自
# 在100則正向評論中，您的預測準度為: 65.0 %

# %%
y_predict
# Out:
# array([[0.990177  , 0.00982303]], dtype=float32)
